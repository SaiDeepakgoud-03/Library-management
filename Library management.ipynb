# %%
#Mini Library management Python project
import datetime
import os
#os.getcwd()

class LMS:
    """
    This class is used to keep records of books in library.It consist of four different functions which is used to represent the 
    different properties of the library like "Displaying the books","Issuing of books", "Returing of books" and "Adding the new books to the library".
    """

    def __init__(self, list_of_books, library_name):
        self.list_of_books = "C:/Users/sai55/OneDrive/Desktop/Library management/List_of_books.txt"
        self.library_name = library_name
        self.books_dict = {}
        id = 101
        with open(self.list_of_books) as b:
            content = b.readlines()
        for line in content:
            self.books_dict.update({str(id):{'books_title':line.replace("\n",""),'lender_name':'','lend_date':'', 'status':'Available'}})
            id= id + 1  
#Displaying the books in the library

    def display_books(self):
        print("------------------------List of Books---------------------")
        print("Books ID", "\t", "Title")
        print("----------------------------------------------------------")
        for key, value in self.books_dict.items():
            print(key, "\t\t", value.get("books_title"), "- [", value.get("status"), "]")
            
#Explains about the issuing of the book to the lender with the time and the name

    def Issue_books(self):
        books_id = input("Enter Book ID: ")
        current_date = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")  # Current date and time
        if books_id in self.books_dict.keys():
            if self.books_dict[books_id]['status'] != 'Available':
                print(f"This book is already issued to {self.books_dict[books_id]['lender_name']} on {self.books_dict[books_id]['lend_date']}.")
            else:
                your_name = input("Enter Your Name: ")
                self.books_dict[books_id]['lender_name'] = your_name
                self.books_dict[books_id]['lend_date'] = current_date
                self.books_dict[books_id]['status'] = 'Already Issued'
                print(f"Book Issued Successfully on {current_date}!\n")  # Print the date when the book is issued
        else:
            print("Book ID Not Found!")
            
# Adding the new books to the library!

    def add_books(self):
        new_books = input("Enter Books Title : ")
        if new_books == "":
            return self.add_books()
        elif len(new_books) > 20:
            print("Books title length is too long !!! Title length limit is 20 characters")
            return self.add_books()
        else:
            with open(self.list_of_books, "a") as b:
                b.writelines(f"{new_books}\n")
            self.books_dict.update({str(int(max(self.books_dict))+1):{'books_title':new_books,'lender_name':'','lend_date':'', 'status':'Available'}})
            print(f"The books '{new_books}' has been added successfully !!!")
            
#getting back to lirary from the lender

    def return_books(self):
        books_id = input("Enter Books ID : ")
        if books_id in self.books_dict.keys():
            if self.books_dict[books_id]['status'] == 'Available':
                print("This book is already available in library. Please check book id. !!! ")
                return self.return_books()
            elif not self.books_dict[books_id]['status'] == 'Available':
                self.books_dict[books_id]['lender_name'] = ''
                self.books_dict[books_id]['lend_date'] = ''
                self.books_dict[books_id]['status']= 'Available'
                print("Successfully Updated !!!\n")
        else:
            print("Book ID Not Found !!!")
            
#main execution
if __name__ == "__main__":
    try:
        mylms = LMS("list_of_books.txt", "Kanna")
        press_key_list = {"D": "Display Books", "I": "Issue Books", "A": "Add Books", "R": "Return Books", "Q": "Quit"}    
        
        key_press = False
        while not (key_press == "q"):
            print(f"\n----------Welcome To {mylms.library_name}'s Library Management System---------\n")
            for key, value in press_key_list.items():
                print("Press", key, "To", value)
            key_press = input("Press Key : ").lower()
            if key_press == "i":
                print("\nCurrent Selection : ISSUE BOOK\n")
                mylms.Issue_books()
                
            elif key_press == "a":
                print("\nCurrent Selection : ADD BOOK\n")
                mylms.add_books()

            elif key_press == "d":
                print("\nCurrent Selection : DISPLAY BOOKS\n")
                mylms.display_books()
            
            elif key_press == "r":
                print("\nCurrent Selection : RETURN BOOK\n")
                mylms.return_books()
            elif key_press == "q":
                break
            else:
                continue
    except Exception as e:
        print("Something went wrong. Please check. !!!")
# Out:
# ----------Welcome To Kanna's Library Management System---------
#
# Press D To Display Books
# Press I To Issue Books
# Press A To Add Books
# Press R To Return Books
# Press Q To Quit
# Press Key : d
#
# Current Selection : DISPLAY BOOKS
#
# ------------------------List of Books---------------------
# Books ID 	 Title
# ----------------------------------------------------------
# 101 		 Pride and Prejudice - [ Available ]
# 102 		 Invisible Man  - [ Available ]
# 103 		 Jane Eyre - [ Available ]
# 104 		 Harry Potter  - [ Available ]
# 105 		 Beloved - [ Available ]
# 106 		 Sense and Sensibility - [ Available ]
# 107 		 Things Fall Apart - [ Available ]
# 108 		 Jane Eyre - [ Available ]
# 109 		 The Color Purple  - [ Available ]
# 110 		 Taming Flame - [ Available ]
# 111 		 2 States - [ Available ]
# 112 		 IoT Basics - [ Available ]
# 113 		 DBMS - [ Available ]
# 114 		 Data Structures using Java - [ Available ]
# 115 		 Operating Systems - [ Available ]
# 116 		 Computer Networks - [ Available ]
# 117 		 Core python - [ Available ]
# 118 		 Internet of vehicles - [ Available ]
#
# ----------Welcome To Kanna's Library Management System---------
#
# Press D To Display Books
# Press I To Issue Books
# Press A To Add Books
# Press R To Return Books
# Press Q To Quit
# Press Key : i
#
# Current Selection : ISSUE BOOK
#
# Enter Book ID: 101
# Enter Your Name: l
# Book Issued Successfully on 2024-09-23 17:51:49!
#
#
# ----------Welcome To Kanna's Library Management System---------
#
# Press D To Display Books
# Press I To Issue Books
# Press A To Add Books
# Press R To Return Books
# Press Q To Quit
# Press Key :
#
# ----------Welcome To Kanna's Library Management System---------
#
# Press D To Display Books
# Press I To Issue Books
# Press A To Add Books
# Press R To Return Books
# Press Q To Quit
# Press Key : i
#
# Current Selection : ISSUE BOOK
#
# Enter Book ID: 105
# Enter Your Name: hh
# Book Issued Successfully on 2024-09-23 17:52:01!
#
#
# ----------Welcome To Kanna's Library Management System---------
#
# Press D To Display Books
# Press I To Issue Books
# Press A To Add Books
# Press R To Return Books
# Press Q To Quit
# Press Key : d
#
# Current Selection : DISPLAY BOOKS
#
# ------------------------List of Books---------------------
# Books ID 	 Title
# ----------------------------------------------------------
# 101 		 Pride and Prejudice - [ Already Issued ]
# 102 		 Invisible Man  - [ Available ]
# 103 		 Jane Eyre - [ Available ]
# 104 		 Harry Potter  - [ Available ]
# 105 		 Beloved - [ Already Issued ]
# 106 		 Sense and Sensibility - [ Available ]
# 107 		 Things Fall Apart - [ Available ]
# 108 		 Jane Eyre - [ Available ]
# 109 		 The Color Purple  - [ Available ]
# 110 		 Taming Flame - [ Available ]
# 111 		 2 States - [ Available ]
# 112 		 IoT Basics - [ Available ]
# 113 		 DBMS - [ Available ]
# 114 		 Data Structures using Java - [ Available ]
# 115 		 Operating Systems - [ Available ]
# 116 		 Computer Networks - [ Available ]
# 117 		 Core python - [ Available ]
# 118 		 Internet of vehicles - [ Available ]
#
# ----------Welcome To Kanna's Library Management System---------
#
# Press D To Display Books
# Press I To Issue Books
# Press A To Add Books
# Press R To Return Books
# Press Q To Quit
# Press Key : q
